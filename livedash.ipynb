# %%
import datetime
import httpx
import pandas as pd


def get_wayback_machine_captures(url: str):
    """
    Get a list of all the captures for a given URL in the Wayback Machine.
    """
    try:
        resp = httpx.get(
            "http://web.archive.org/cdx/search/cdx",
            params={"url": url, "output": "json"},
            timeout=60  # Increased timeout to 60 seconds
        )
    except httpx.ReadTimeout:
        print("The request timed out. Please try again later.")
        return []
    resp.raise_for_status()

    # What if we don't get any results?
    if resp.json() == []:
        return []

    fields, *remainder = resp.json()

    captures = []
    for row in remainder:
        data = dict(zip(fields, row))

        data["length"] = int(data["length"])

        # The format used for Wayback captures is yyyyMMddhhmmss
        # e.g. 20200814072506
        data["time"] = datetime.datetime.strptime(data["timestamp"], "%Y%m%d%H%M%S")

        # The capture URL is of the format:
        # https://web.archive.org/web/{timestamp}/{original}
        data["raw_url"] = f"https://web.archive.org/web/{data['timestamp']}if_/{data['original']}"
        data["web_url"] = f"https://web.archive.org/web/{data['timestamp']}/{data['original']}"

        captures.append(data)

    return captures


def filter_captures_last_week(captures):
    """
    Filter captures to include only those from the previous week.
    """
    one_week_ago = datetime.datetime.now() - datetime.timedelta(days=7)
    filtered_captures = [
        capture for capture in captures if one_week_ago <= capture["time"] <= datetime.datetime.now()
    ]
    return pd.DataFrame(filtered_captures)


# Get captures and filter them
captures = get_wayback_machine_captures(url="https://www.youtube.com/channel/UCYfdidRxbB8Qhf0Nx7ioOYw")
df = filter_captures_last_week(captures)

print(df)
# Out:
#                                            urlkey       timestamp  \
# 0   com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250415033055
# 1   com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250415053525
# 2   com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250415074011
# 3   com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250415094849
# 4   com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250416000531
# 5   com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250416020714
# 6   com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250416042851
# 7   com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250416065718
# 8   com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250417021039
# 9   com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250417061831
# 10  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250417083634
# 11  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250418011732
# 12  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250418031927
# 13  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250418052027
# 14  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250418072422
# 15  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250419015944
# 16  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250419040103
# 17  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250419060209
# 18  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250419080623
# 19  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250420012224
# 20  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250420032402
# 21  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250420053230
# 22  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250420073810
# 23  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250420094953
# 24  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250421005131
# 25  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250421025723
# 26  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250421052126
# 27  com,youtube)/channel/ucyfdidrxbb8qhf0nx7iooyw  20250422020422
#
#                                              original   mimetype statuscode  \
# 0   https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 1   https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 2   https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 3   https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 4   https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 5   https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 6   https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 7   https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 8   https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 9   https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 10  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 11  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 12  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 13  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 14  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 15  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 16  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 17  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 18  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 19  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 20  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 21  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 22  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 23  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 24  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 25  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 26  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
# 27  https://www.youtube.com/channel/UCYfdidRxbB8Qh...  text/html        200
#
#                               digest  length                time  \
# 0   VHP5SNLME47K43F4W5FPPBPLEZLW4DJ4  342165 2025-04-15 03:30:55
# 1   OXWUZA6IYX72VXLMXX2FM5HXAUEFRVBJ  343915 2025-04-15 05:35:25
# 2   4BL5LOAJ4HEDRBURWOIAESFTIZUQL2EP  337886 2025-04-15 07:40:11
# 3   VYUXCMTH27UEGBORKHXIIBBZGP36PYRG  323261 2025-04-15 09:48:49
# 7   https://web.archive.org/web/20250416065718if_/...
# 8   https://web.archive.org/web/20250417021039if_/...
# 9   https://web.archive.org/web/20250417061831if_/...
# 10  https://web.archive.org/web/20250417083634if_/...
# 11  https://web.archive.org/web/20250418011732if_/...
# 12  https://web.archive.org/web/20250418031927if_/...
# 13  https://web.archive.org/web/20250418052027if_/...
# 14  https://web.archive.org/web/20250418072422if_/...
# 15  https://web.archive.org/web/20250419015944if_/...
# 16  https://web.archive.org/web/20250419040103if_/...
# 17  https://web.archive.org/web/20250419060209if_/...
# 18  https://web.archive.org/web/20250419080623if_/...
# 19  https://web.archive.org/web/20250420012224if_/...
# 20  https://web.archive.org/web/20250420032402if_/...
# 21  https://web.archive.org/web/20250420053230if_/...
# 22  https://web.archive.org/web/20250420073810if_/...
# 23  https://web.archive.org/web/20250420094953if_/...
# 24  https://web.archive.org/web/20250421005131if_/...
# 25  https://web.archive.org/web/20250421025723if_/...
# 26  https://web.archive.org/web/20250421052126if_/...
# 27  https://web.archive.org/web/20250422020422if_/...
#
#                                               web_url
# 0   https://web.archive.org/web/20250415033055/htt...
# 1   https://web.archive.org/web/20250415053525/htt...
# 2   https://web.archive.org/web/20250415074011/htt...
# 3   https://web.archive.org/web/20250415094849/htt...
# 4   https://web.archive.org/web/20250416000531/htt...
# 5   https://web.archive.org/web/20250416020714/htt...
# 6   https://web.archive.org/web/20250416042851/htt...
# 7   https://web.archive.org/web/20250416065718/htt...
# 8   https://web.archive.org/web/20250417021039/htt...
# 9   https://web.archive.org/web/20250417061831/htt...
# 10  https://web.archive.org/web/20250417083634/htt...
# 11  https://web.archive.org/web/20250418011732/htt...
# 12  https://web.archive.org/web/20250418031927/htt...
# 13  https://web.archive.org/web/20250418052027/htt...
# 14  https://web.archive.org/web/20250418072422/htt...
# 15  https://web.archive.org/web/20250419015944/htt...
# 16  https://web.archive.org/web/20250419040103/htt...
# 17  https://web.archive.org/web/20250419060209/htt...
# 18  https://web.archive.org/web/20250419080623/htt...
# 19  https://web.archive.org/web/20250420012224/htt...
# 20  https://web.archive.org/web/20250420032402/htt...
# 21  https://web.archive.org/web/20250420053230/htt...
# 22  https://web.archive.org/web/20250420073810/htt...
# 23  https://web.archive.org/web/20250420094953/htt...
# 24  https://web.archive.org/web/20250421005131/htt...
# 25  https://web.archive.org/web/20250421025723/htt...
# 26  https://web.archive.org/web/20250421052126/htt...
# 27  https://web.archive.org/web/20250422020422/htt...

# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#      |████████████████████████████████| 187 kB 1.4 MB/s eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/jackstein/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4) (4.12.2)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.13.4 soupsieve-2.7
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests


url = 'https://web.archive.org/web/20140307210234/https://www.youtube.com/channel/UCYfdidRxbB8Qhf0Nx7ioOYw'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content of the page
soup = BeautifulSoup(response.text, 'html.parser')

# Example: Extract all the links on the page
links = soup.find_all('title')

titles = soup.find_all('title')
# Print the links
for link in links:
    href = link.get('href')
    print(href)
# Out:
# None
